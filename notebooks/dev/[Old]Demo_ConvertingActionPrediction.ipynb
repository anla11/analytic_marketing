# %% [markdown]
# # Dependencies

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

# %% [markdown]
# # Import from projects

# %%
from propensity_prediction.tasks.converting_action_prediction.converting_action_prediction import Ensemble_NextAction

# %% [markdown]
# # Experiments

# %% [markdown]
# ### Load data

# %%
# !pip install kaggle
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# Requirement already satisfied: kaggle in /root/.local/share/virtualenvs/src-NVTF7jWz/lib/python3.7/site-packages (1.5.6)
# Requirement already satisfied: python-dateutil in /root/.local/share/virtualenvs/src-NVTF7jWz/lib/python3.7/site-packages (from kaggle) (2.8.1)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /root/.local/share/virtualenvs/src-NVTF7jWz/lib/python3.7/site-packages (from kaggle) (1.24.3)
# Requirement already satisfied: requests in /root/.local/share/virtualenvs/src-NVTF7jWz/lib/python3.7/site-packages (from kaggle) (2.24.0)
# Requirement already satisfied: certifi in /root/.local/share/virtualenvs/src-NVTF7jWz/lib/python3.7/site-packages (from kaggle) (2020.6.20)
# Requirement already satisfied: six>=1.10 in /root/.local/share/virtualenvs/src-NVTF7jWz/lib/python3.7/site-packages (from kaggle) (1.15.0)
# Requirement already satisfied: tqdm in /root/.local/share/virtualenvs/src-NVTF7jWz/lib/python3.7/site-packages (from kaggle) (4.48.0)
# Requirement already satisfied: python-slugify in /root/.local/share/virtualenvs/src-NVTF7jWz/lib/python3.7/site-packages (from kaggle) (4.0.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /root/.local/share/virtualenvs/src-NVTF7jWz/lib/python3.7/site-packages (from requests->kaggle) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /root/.local/share/virtualenvs/src-NVTF7jWz/lib/python3.7/site-packages (from requests->kaggle) (2.10)
# Requirement already satisfied: text-unidecode>=1.3 in /root/.local/share/virtualenvs/src-NVTF7jWz/lib/python3.7/site-packages (from python-slugify->kaggle) (1.3)

# %%
# !kaggle datasets download mkechinov/ecommerce-events-history-in-cosmetics-shop -f 2019-Dec.csv

import zipfile
zip_ref = zipfile.ZipFile('426888%2F1015349%2Fcompressed%2F2019-Dec.csv.zip', 'r')
zip_ref.extractall()
zip_ref.close()
# !rm 426888%2F1015349%2Fcompressed%2F2019-Dec.csv.zip
# Out:
# Downloading 426888%2F1015349%2Fcompressed%2F2019-Dec.csv.zip to /src/ConvertingActionPrediction
#  99%|█████████████████████████████████████▌| 73.0M/73.8M [00:09<00:00, 7.34MB/s]
# 100%|██████████████████████████████████████| 73.8M/73.8M [00:09<00:00, 7.96MB/s]

# %%
df = pd.read_csv('./2019-Dec.csv', dtype = str)
df['price'] = pd.to_numeric(df['price'])
df = df[df['price']>= 0]
df
# Out:
#                       event_time        event_type product_id  \
# 0        2019-12-01 00:00:00 UTC  remove_from_cart    5712790
# 1        2019-12-01 00:00:00 UTC              view    5764655
# 2        2019-12-01 00:00:02 UTC              cart       4958
# 3        2019-12-01 00:00:05 UTC              view    5848413
# 4        2019-12-01 00:00:07 UTC              view    5824148
# ...                          ...               ...        ...
# 3533281  2019-12-31 23:59:39 UTC              view    5683350
# 3533282  2019-12-31 23:59:46 UTC              view    5888097
# 3533283  2019-12-31 23:59:51 UTC              view      59975
# 3533284  2019-12-31 23:59:52 UTC              view    5775982
# 3533285  2019-12-31 23:59:57 UTC              view    5635090
#
#                  category_id category_code      brand   price    user_id  \
# 0        1487580005268456287           NaN      f.o.x    6.27  576802932
# 1        1487580005411062629           NaN        cnd   29.05  412120092
# 2        1487580009471148064           NaN     runail    1.19  494077766
# 3        1487580007675986893           NaN  freedecor    0.79  348405118
# 4        1487580005511725929           NaN        NaN    5.56  576005683
# ...                      ...           ...        ...     ...        ...
# 3533281  1487580005671109489           NaN     masura    2.84  536812729
# 3533282  1487580013388628160           NaN       shik  179.05  503658154
# 3533283  1487580012096782476           NaN        NaN    7.14  595414541
# 3533284  1783999063314661546           NaN        NaN   11.90  397780878
# 3533285  1487580005754995573           NaN        NaN    4.44  420652863
#
#                                  user_session
# 0        51d85cb0-897f-48d2-918b-ad63965c12dc
# 1        8adff31e-2051-4894-9758-224bfa8aec18
# 2        c99a50e8-2fac-4c4d-89ec-41c05f114554
# 3        722ffea5-73c0-4924-8e8f-371ff8031af4
# 4        28172809-7e4a-45ce-bab0-5efa90117cd5
# ...                                       ...
# 3533281  e4a2d47c-a956-4c46-8176-745f52ea664b
# 3533282  2dde9867-9e71-4a64-880d-aa68b66aae6d
# 3533283  4c6d80bb-5dd3-4fbb-b592-187b51db2753
# 3533284  7e8a2b85-153a-44eb-a71f-b748fde14fcc
# 3533285  546f6af3-a517-4752-a98b-80c4c5860711
#
# [3533268 rows x 9 columns]

# %% [markdown]
# ### Split data

# %%
data_train, data_test = train_test_split(df, test_size = 0.2, random_state = 0)

# %% [markdown]
# ### Config

# %%
INPUT_CONFIG = {
	'user_id':'user_id',
	'product_id': 'product_id',
	'user_session':'user_session',
	'event': 'event_type',
	'order_actions': [{'source': 'view', 'des':'cart'},{'source': 'cart', 'des':'remove_from_cart'},{'source': 'cart', 'des':'purchase'}],
	'input_features': []
}

FE_CONFIG = []
MODEL_CONFIG=['NextAction_BinaryClass', 'NextAction_MultiClass']
PREDICT_CONFIG={'method':'gettop','ntop':None}
PIPELINE_CONFIG = {'task': 'converting_action_prediction', 'input_config':INPUT_CONFIG, 'fe_config':FE_CONFIG, 'model_config':MODEL_CONFIG, 'predict_config':PREDICT_CONFIG}

# %% [markdown]
# ### Apply model

# %%
PIPELINE_CONFIG
# Out:
# {'task': 'converting_action_prediction',
#  'input_config': {'user_id': 'user_id',
#   'product_id': 'product_id',
#   'user_session': 'user_session',
#   'event': 'event_type',
#   'order_actions': [{'source': 'view', 'des': 'cart'},
#    {'source': 'cart', 'des': 'remove_from_cart'},
#    {'source': 'cart', 'des': 'purchase'}],
#   'input_features': []},
#  'fe_config': [],
#  'model_config': ['NextAction_BinaryClass', 'NextAction_MultiClass'],
#  'predict_config': {'method': 'gettop', 'ntop': None}}

# %%
model = Ensemble_NextAction(PIPELINE_CONFIG['model_config'],PIPELINE_CONFIG['fe_config'],PIPELINE_CONFIG['input_config'])
# Out:
# NextAction_BinaryClass
# NextAction_MultiClass

# %%
model.train(data_train)
# Out:
# ...Training model:  NextAction_BinaryClass
# Trained mode:  NextAction_BinaryClass
# ...Training model:  NextAction_MultiClass
# /src/ConvertingActionPrediction/propensity_prediction/model/converting_action_prediction/converting_action_prediction.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label_df[self.event] = 0
# /src/ConvertingActionPrediction/propensity_prediction/model/converting_action_prediction/converting_action_prediction.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   label_df[self.event] = np.where(label_df[label] > 0, labels[label], label_df[self.event] )
# Trained mode:  NextAction_MultiClass

# %%
model.predict(data_test)
# Out:
# [{'NextAction_BinaryClass': [{'view2cart': array([0, 0, 0, ..., 0, 0, 0])},
#    {'cart2remove_from_cart': array([0, 0, 0, ..., 0, 0, 0])},
#    {'cart2purchase': array([0, 0, 0, ..., 0, 0, 1])}]},
#  {'NextAction_MultiClass': array([0, 0, 0, ..., 0, 0, 3])}]

# %%
model.get_probabilities(data_test)
# Out:
# [{'NextAction_BinaryClass': [{'view2cart': array([0.07358817, 0.05644277, 0.07304702, ..., 0.04485092, 0.12914056,
#            0.07802456])},
#    {'cart2remove_from_cart': array([0.06147493, 0.05374116, 0.0515187 , ..., 0.03374003, 0.03667009,
#            0.04846276])},
#    {'cart2purchase': array([0.02982722, 0.03414972, 0.03720878, ..., 0.02387373, 0.02387373,
#            0.99684254])}]},
#  {'NextAction_MultiClass': array([[0.69498775, 0.27894423, 0.02225973, 0.00380829],
#          [0.81034441, 0.16579867, 0.02013145, 0.00372546],
#          [0.67654311, 0.29257131, 0.02573288, 0.00515269],
#          ...,
#          [0.87136381, 0.11701361, 0.00902726, 0.00259531],
#          [0.90737761, 0.08561549, 0.00590172, 0.00110518],
#          [0.00904959, 0.00238071, 0.0020798 , 0.9864899 ]])}]

# %%
model.evaluate(data_test)
# Out:
# /src/ConvertingActionPrediction/propensity_prediction/utils/image_threshold.py:28: RuntimeWarning: invalid value encountered in true_divide
#   mean1 = np.cumsum(hist * bin_centers) / weight1
# /src/ConvertingActionPrediction/propensity_prediction/utils/image_threshold.py:63: RuntimeWarning: divide by zero encountered in reciprocal
#   crit = np.log(((P1_sq[:-1] * P2_sq[1:]) ** -1) *
# /src/ConvertingActionPrediction/propensity_prediction/utils/image_threshold.py:64: RuntimeWarning: invalid value encountered in multiply
#   (P1[:-1] * (1.0 - P1[:-1])) ** 2)
# /src/ConvertingActionPrediction/propensity_prediction/evaluation/binaryclass_evaluate.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   recall = 1.0*n_tp/(n_tp+n_fn)
# /src/ConvertingActionPrediction/propensity_prediction/utils/image_threshold.py:28: RuntimeWarning: invalid value encountered in true_divide
#   mean1 = np.cumsum(hist * bin_centers) / weight1
# /src/ConvertingActionPrediction/propensity_prediction/utils/image_threshold.py:63: RuntimeWarning: divide by zero encountered in reciprocal
#   crit = np.log(((P1_sq[:-1] * P2_sq[1:]) ** -1) *
# /src/ConvertingActionPrediction/propensity_prediction/utils/image_threshold.py:64: RuntimeWarning: invalid value encountered in multiply
#   (P1[:-1] * (1.0 - P1[:-1])) ** 2)
# /src/ConvertingActionPrediction/propensity_prediction/evaluation/binaryclass_evaluate.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   recall = 1.0*n_tp/(n_tp+n_fn)
# /src/ConvertingActionPrediction/propensity_prediction/utils/image_threshold.py:28: RuntimeWarning: invalid value encountered in true_divide
#   mean1 = np.cumsum(hist * bin_centers) / weight1
# /src/ConvertingActionPrediction/propensity_prediction/utils/image_threshold.py:63: RuntimeWarning: divide by zero encountered in reciprocal
#   crit = np.log(((P1_sq[:-1] * P2_sq[1:]) ** -1) *
# /src/ConvertingActionPrediction/propensity_prediction/utils/image_threshold.py:64: RuntimeWarning: invalid value encountered in multiply
#   (P1[:-1] * (1.0 - P1[:-1])) ** 2)
# /src/ConvertingActionPrediction/propensity_prediction/evaluation/binaryclass_evaluate.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   recall = 1.0*n_tp/(n_tp+n_fn)
# /src/ConvertingActionPrediction/propensity_prediction/evaluation/binaryclass_evaluate.py:26: RuntimeWarning: invalid value encountered in double_scalars
#   recall = 1.0*n_tp/(n_tp+n_fn)
# [{'NextAction_BinaryClass': [{'view2cart': {'model_performance': {'auc': 0.9451934552967809,
#       'predicting': [{'method': 'threshold',
#         'results': [{'threshold_method': 'constant',
#           'results': {'accuracy': 0.9586547664471791,
#            'precision': 0.4217642922818973,
#            'recall': 0.4725201478519057,
#            'trueneg_rate': 0.9806827713843164,
#            'f1_score': 0.4457018747142204}},
#          {'threshold_method': 'baseline',
#           'results': {'accuracy': 0.965533559428977,
#            'precision': 0.21109849099464548,
#            'recall': 0.7114473204520598,
#            'trueneg_rate': 0.996487171407395,
#            'f1_score': 0.3255891553701773}},
#          {'threshold_method': 'kmeans',
#           'results': {'accuracy': 0.9468625499069541,
#            'precision': 0.5557899291470604,
#            'recall': 0.38071949909229,
#            'trueneg_rate': 0.9629078143238193,
#            'f1_score': 0.4518909410729991}},
#          {'threshold_method': 'otsu',
#           'results': {'accuracy': 0.03941183868622941,
#            'precision': 1.0,
#            'recall': 0.03941183868622941,
#            'trueneg_rate': 0.0,
#            'f1_score': 0.0758348851135739}},
#          {'threshold_method': 'yen',
#           'results': {'accuracy': 0.03941183868622941,
#            'precision': 1.0,
#            'recall': 0.03941183868622941,
#            'trueneg_rate': 0.0,
#            'f1_score': 0.0758348851135739}}]},
#        {'method': 'gettop',
#         'results': [{'ntop': 0,
#           'results': {'accuracy': 0.9605881613137706,
#            'precision': 0.0,
#            'recall': nan,
#            'trueneg_rate': 1.0,
#            'f1_score': nan}},
#          {'ntop': 18489,
#           'results': {'accuracy': 0.9568343483478746,
#            'precision': 0.4523770890799935,
#            'recall': 0.4523770890799935,
#            'trueneg_rate': 0.9775316554010571,
#            'f1_score': 0.4523770890799935}},
#          {'ntop': 65401,
#           'results': {'accuracy': 0.8868484384692288,
#            'precision': 0.8331440315863486,
#            'recall': 0.23553156679561474,
#            'trueneg_rate': 0.8890518691443611,
#            'f1_score': 0.36724281797592084}}]}]}}},
#    {'cart2remove_from_cart': {'model_performance': {'auc': 0.9057605450878894,
#       'predicting': [{'method': 'threshold',
#         'results': [{'threshold_method': 'constant',
#           'results': {'accuracy': 0.9272241090045814,
#            'precision': 0.15940229681195406,
#            'recall': 0.8385817588056916,
#            'trueneg_rate': 0.9972035206543438,
#            'f1_score': 0.26788375558867367}},
#          {'threshold_method': 'baseline',
#           'results': {'accuracy': 0.9221501664771654,
#            'precision': 0.06801755863964883,
#            'recall': 0.9993485342019544,
#            'trueneg_rate': 0.9999959588448762,
#            'f1_score': 0.12736632348057125}},
#          {'threshold_method': 'kmeans',
#           'results': {'accuracy': 0.927294477550582,
#            'precision': 0.2602757947944841,
#            'recall': 0.665683828532547,
#            'trueneg_rate': 0.9880866746950948,
#            'f1_score': 0.3742309776545217}},
#          {'threshold_method': 'otsu',
#           'results': {'accuracy': 0.08352746410278251,
#            'precision': 1.0,
#            'recall': 0.08352746410278251,
#            'trueneg_rate': 0.0,
#            'f1_score': 0.15417692097347552}},
#          {'threshold_method': 'yen',
#           'results': {'accuracy': 0.08352746410278251,
#            'precision': 1.0,
#            'recall': 0.08352746410278251,
#            'trueneg_rate': 0.0,
#            'f1_score': 0.15417692097347552}}]},
#        {'method': 'gettop',
#         'results': [{'ntop': 0,
#           'results': {'accuracy': 0.9164725358972174,
#            'precision': 0.0,
#            'recall': nan,
#            'trueneg_rate': 1.0,
#            'f1_score': nan}},
#          {'ntop': 22553,
#           'results': {'accuracy': 0.912431899913706,
#            'precision': 0.4758125304837494,
#            'recall': 0.4758125304837494,
#            'trueneg_rate': 0.952225464126666,
#            'f1_score': 0.47581253048374933}},
#          {'ntop': 49553,
#           'results': {'accuracy': 0.8544778468706367,
#            'precision': 0.7274863654502727,
#            'recall': 0.33110003430670193,
#            'trueneg_rate': 0.8660518722671688,
#            'f1_score': 0.45508002108007656}}]}]}}},
#    {'cart2purchase': {'model_performance': {'auc': 0.9545169312462284,
#       'predicting': [{'method': 'threshold',
#         'results': [{'threshold_method': 'constant',
#           'results': {'accuracy': 0.9608502426758669,
#            'precision': 0.32227635534363014,
#            'recall': 0.6751357220412595,
#            'trueneg_rate': 0.9923503694423849,
#            'f1_score': 0.4362896435587988}},
#          {'threshold_method': 'baseline',
#           'results': {'accuracy': 0.9589351499912285,
#            'precision': 0.12947030164818077,
#            'recall': 0.9773082942097027,
#            'trueneg_rate': 0.9998517117071051,
#            'f1_score': 0.22864988558352398}},
#          {'threshold_method': 'kmeans',
#           'results': {'accuracy': 0.9608161316102373,
#            'precision': 0.31564216854980826,
#            'recall': 0.6790811775200714,
#            'trueneg_rate': 0.9926418326387646,
#            'f1_score': 0.43096737668954777}},
#          {'threshold_method': 'otsu',
#           'results': {'accuracy': 0.04700992144708886,
#            'precision': 1.0,
#            'recall': 0.04700992144708886,
#            'trueneg_rate': 0.0,
#            'f1_score': 0.08979842594445658}},
#          {'threshold_method': 'yen',
#           'results': {'accuracy': 0.04700992144708886,
#            'precision': 1.0,
#            'recall': 0.04700992144708886,
#            'trueneg_rate': 0.0,
#            'f1_score': 0.08979842594445658}}]},
#        {'method': 'gettop',
#         'results': [{'ntop': 0,
#           'results': {'accuracy': 0.9529900785529112,
#            'precision': 0.0,
#            'recall': nan,
#            'trueneg_rate': 1.0,
#            'f1_score': nan}},
#          {'ntop': 9647,
#           'results': {'accuracy': 0.9531996179560649,
#            'precision': 0.5022286721260496,
#            'recall': 0.5022286721260496,
#            'trueneg_rate': 0.9754455040523611,
#            'f1_score': 0.5022286721260496}},
#          {'ntop': 30168,
#           'results': {'accuracy': 0.8885591485878018,
#            'precision': 0.8783041360008292,
#            'recall': 0.2808605144523999,
#            'trueneg_rate': 0.8890650167463503,
#            'f1_score': 0.4256184854954163}}]}]}}}]},
#  {'NextAction_MultiClass': [{'view2cart': {'model_performance': {'auc': 0.9184407718383861,
#       'predicting': [{'method': 'threshold',
#         'results': [{'threshold_method': 'constant',
#           'results': {'accuracy': 0.9153687360107623,
#            'precision': 0.41500351560387255,
#            'recall': 0.6700139713587147,
#            'trueneg_rate': 0.9754554606566428,
#            'f1_score': 0.5125413312848602}},
#          {'threshold_method': 'baseline',
#           'results': {'accuracy': 0.9100049868370695,
#            'precision': 0.19308778192438747,
#            'recall': 0.8559098537520978,
#            'trueneg_rate': 0.9960965154418212,
#            'f1_score': 0.3150926743159753}},
#          {'threshold_method': 'kmeans',
#           'results': {'accuracy': 0.9111473204448722,
#            'precision': 0.531397046892747,
#            'recall': 0.5960325163795195,
#            'trueneg_rate': 0.9567499106939888,
#            'f1_score': 0.5618620078346153}},
#          {'threshold_method': 'otsu',
#           'results': {'accuracy': 0.9107356164542428,
#            'precision': 0.5350208231921684,
#            'recall': 0.5927257474983522,
#            'trueneg_rate': 0.9558536030916117,
#            'f1_score': 0.5623969526408551}},
#          {'threshold_method': 'yen',
#           'results': {'accuracy': 0.8976248738794114,
#            'precision': 0.6538482340851317,
#            'recall': 0.5178632625085675,
#            'trueneg_rate': 0.9268989705452538,
#            'f1_score': 0.5779647646594793}}]},
#        {'method': 'gettop',
#         'results': [{'ntop': 1243,
#           'results': {'accuracy': 0.8999965208113468,
#            'precision': 0.06722916328627833,
#            'recall': 1.0,
#            'trueneg_rate': 1.0,
#            'f1_score': 0.12598824244881413}},
#          {'ntop': 18489,
#           'results': {'accuracy': 0.9075347628932933,
#            'precision': 0.5687706203688679,
#            'recall': 0.5687706203688679,
#            'trueneg_rate': 0.9482155035235281,
#            'f1_score': 0.5687706203688679}},
#          {'ntop': 35734,
#           'results': {'accuracy': 0.860409152585617,
#            'precision': 0.8153496673697874,
#            'recall': 0.4218671293446018,
#            'trueneg_rate': 0.8658201539310882,
#            'f1_score': 0.5560371060251186}}]}]}}},
#    {'cart2remove_from_cart': {'model_performance': {'auc': 0.9058530831829964,
#       'predicting': [{'method': 'threshold',
#         'results': [{'threshold_method': 'constant',
#           'results': {'accuracy': 0.8806232386607443,
#            'precision': 0.08947811821043763,
#            'recall': 0.9748792270531401,
#            'trueneg_rate': 0.9996531043822257,
#            'f1_score': 0.1639117897900337}},
#          {'threshold_method': 'baseline',
#           'results': {'accuracy': 0.8703074443039883,
#            'precision': 0.008291579834168403,
#            'recall': 1.0,
#            'trueneg_rate': 1.0,
#            'f1_score': 0.016446789797713277}},
#          {'threshold_method': 'kmeans',
#           'results': {'accuracy': 0.8831920396163615,
#            'precision': 0.11377643772447124,
#            'recall': 0.9423430040396621,
#            'trueneg_rate': 0.9989526420771042,
#            'f1_score': 0.203038455451812}},
#          {'threshold_method': 'otsu',
#           'results': {'accuracy': 0.8832152342073828,
#            'precision': 0.11408681771826365,
#            'recall': 0.9414562751555068,
#            'trueneg_rate': 0.9989326288683865,
#            'f1_score': 0.20351182472514437}},
#          {'threshold_method': 'yen',
#           'results': {'accuracy': 0.8871061268512183,
#            'precision': 0.15909191681816168,
#            'recall': 0.8768328445747801,
#            'trueneg_rate': 0.9966377809354173,
#            'f1_score': 0.26931882154250336}}]},
#        {'method': 'gettop',
#         'results': [{'ntop': 5307,
#           'results': {'accuracy': 0.8898256926484743,
#            'precision': 0.19642619607147607,
#            'recall': 0.8347465611456567,
#            'trueneg_rate': 0.9941494719848434,
#            'f1_score': 0.3180186647523331}},
#          {'ntop': 22553,
#           'results': {'accuracy': 0.8836443341412783,
#            'precision': 0.5551367888972643,
#            'recall': 0.5551367888972643,
#            'trueneg_rate': 0.933069158978259,
#            'f1_score': 0.5551367888972643}},
#          {'ntop': 39798,
#           'results': {'accuracy': 0.8391629072100386,
#            'precision': 0.7673923646521527,
#            'recall': 0.43487109905020355,
#            'trueneg_rate': 0.8499609742430004,
#            'f1_score': 0.5551474715722282}}]}]}}},
#    {'cart2purchase': {'model_performance': {'auc': 0.9466469817455248,
#       'predicting': [{'method': 'threshold',
#         'results': [{'threshold_method': 'constant',
#           'results': {'accuracy': 0.9522133438482145,
#            'precision': 0.15756193635327045,
#            'recall': 0.9302325581395349,
#            'trueneg_rate': 0.9992997844073044,
#            'f1_score': 0.26947965605886004}},
#          {'threshold_method': 'baseline',
#           'results': {'accuracy': 0.9460957704663272,
#            'precision': 0.03638436819736706,
#            'recall': 1.0,
#            'trueneg_rate': 1.0,
#            'f1_score': 0.07021404280856172}},
#          {'threshold_method': 'kmeans',
#           'results': {'accuracy': 0.952862792396813,
#            'precision': 0.17632424587954804,
#            'recall': 0.9028662420382165,
#            'trueneg_rate': 0.9988759697064623,
#            'f1_score': 0.29503078657531867}},
#          {'threshold_method': 'otsu',
#           'results': {'accuracy': 0.9528511951013023,
#            'precision': 0.17704986006012233,
#            'recall': 0.8989473684210526,
#            'trueneg_rate': 0.9988206895280916,
#            'f1_score': 0.2958344158655928}},
#          {'threshold_method': 'yen',
#           'results': {'accuracy': 0.9552286406809932,
#            'precision': 0.3376179123043433,
#            'recall': 0.709895379250218,
#            'trueneg_rate': 0.9918246758431762,
#            'f1_score': 0.4576044959606603}}]},
#        {'method': 'gettop',
#         'results': [{'ntop': 0,
#           'results': {'accuracy': 0.9440604451042017,
#            'precision': 0.0,
#            'recall': nan,
#            'trueneg_rate': 1.0,
#            'f1_score': nan}},
#          {'ntop': 9647,
#           'results': {'accuracy': 0.9490530808215524,
#            'precision': 0.5446252721053177,
#            'recall': 0.5446252721053177,
#            'trueneg_rate': 0.9730171307130528,
#            'f1_score': 0.5446252721053177}},
#          {'ntop': 26892,
#           'results': {'accuracy': 0.8825947788975611,
#            'precision': 0.8444075878511454,
#            'recall': 0.30291536516436113,
#            'trueneg_rate': 0.8848575306958546,
#            'f1_score': 0.44587974493007476}}]}]}}}]}]
